# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt  
import seaborn as sns          
sns.set(color_codes=1) 
# %matplotlib inline

# %%
df = pd.read_csv('E:/Python notes/exams_data.csv')
df
# Out:
#          StudentId  gender    group parental level of education         lunch  \
# 0      Alphabeta12    male  group A                 high school      standard
# 1      Alphabeta13  female  group D            some high school  free/reduced
# 2      Alphabeta14    male  group E                some college  free/reduced
# 3      Alphabeta15    male  group B                 high school      standard
# 4      Alphabeta16    male  group E          associate's degree      standard
# ..             ...     ...      ...                         ...           ...
# 995  Alphabeta1007    male  group C                 high school      standard
# 996  Alphabeta1008    male  group D          associate's degree  free/reduced
# 997  Alphabeta1009  female  group C            some high school  free/reduced
# 998  Alphabeta1010  female  group C                some college      standard
# 999  Alphabeta1011    male  group A                some college      standard
#
# ...

# %%
pd.set_option('display.max_rows', 1000)
df
# Out:
#          StudentId  gender    group parental level of education         lunch  \
# 0      Alphabeta12    male  group A                 high school      standard
# 1      Alphabeta13  female  group D            some high school  free/reduced
# 2      Alphabeta14    male  group E                some college  free/reduced
# 3      Alphabeta15    male  group B                 high school      standard
# 4      Alphabeta16    male  group E          associate's degree      standard
# 5      Alphabeta17  female  group D                 high school      standard
# 6      Alphabeta18  female  group A           bachelor's degree      standard
# 7      Alphabeta19    male  group E                some college      standard
# 8      Alphabeta20    male  group D                 high school      standard
# 9      Alphabeta21    male  group C                some college  free/reduced
# 10     Alphabeta22    male  group E                some college      standard
# ...

# %%
# check shape of data
df.shape
# Out:
# (1000, 10)

# %%
# check columns in data 
df.columns
# Out:
# Index(['StudentId', 'gender', 'group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Date_of _Evalution'],
#       dtype='object')

# %%
# check information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   StudentId                    1000 non-null   object
#  1   gender                       1000 non-null   object
#  2   group                        1000 non-null   object
#  3   parental level of education  999 non-null    object
#  4   lunch                        999 non-null    object
#  5   test preparation course      1000 non-null   object
#  6   math score                   999 non-null    object
#  7   reading score                1000 non-null   object
#  8   writing score                999 non-null    float64
#  9   Date_of _Evalution           999 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 78.2+ KB

# %%
# check datatype of data 
df.dtypes
# Out:
# StudentId                       object
# gender                          object
# group                           object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                   object
# writing score                  float64
# Date_of _Evalution              object
# dtype: object

# %%
# check unique values of all columns before removing noise
for i in df.columns:
    print(df[i].unique())
# Out:
# ['Alphabeta12' 'Alphabeta13' 'Alphabeta14' 'Alphabeta15' 'Alphabeta16'
#  'Alphabeta17' 'Alphabeta18' 'Alphabeta19' 'Alphabeta20' 'Alphabeta21'
#  'Alphabeta22' 'Alphabeta23' 'Alphabeta24' 'Alphabeta25' 'Alphabeta26'
#  'Alphabeta27' 'Alphabeta28' 'Alphabeta29' 'Alphabeta30' 'Alphabeta31'
#  'Alphabeta32' 'Alphabeta33' 'Alphabeta34' 'Alphabeta35' 'Alphabeta36'
#  'Alphabeta37' 'Alphabeta38' 'Alphabeta39' 'Alphabeta40' 'Alphabeta41'
#  'Alphabeta42' 'Alphabeta43' 'Alphabeta44' 'Alphabeta45' 'Alphabeta46'
#  'Alphabeta47' 'Alphabeta48' 'Alphabeta49' 'Alphabeta50' 'Alphabeta51'
#  'Alphabeta52' 'Alphabeta53' 'Alphabeta54' 'Alphabeta55' 'Alphabeta56'
#  'Alphabeta57' 'Alphabeta58' 'Alphabeta59' 'Alphabeta60' 'Alphabeta61'
#  'Alphabeta62' 'Alphabeta63' 'Alphabeta64' 'Alphabeta65' 'Alphabeta66'
#  'Alphabeta67' 'Alphabeta68' 'Alphabeta69' 'Alphabeta70' 'Alphabeta71'
#  'Alphabeta72' 'Alphabeta73' 'Alphabeta74' 'Alphabeta75' 'Alphabeta76'
# ...

# %%
# Clean the data and remove the noise values from the data.
df.head(2)
# Out:
#      StudentId  gender    group parental level of education         lunch  \
# 0  Alphabeta12    male  group A                 high school      standard
# 1  Alphabeta13  female  group D            some high school  free/reduced
#
#   test preparation course math score reading score  writing score  \
# 0               completed         67            67           63.0
# 1                    none        NaN            59           55.0
#
#   Date_of _Evalution
# 0         17/07/2016
# 1         31/01/2016

# %%
# gender
df = df[~df['gender'].isin(['5','iop'])]

# %%
# parental level of education
df = df[df['parental level of education'] != '&0']

# %%
# lunch
df = df[df.lunch != 'rt4']

# %%
# test preparation course
df = df[df['test preparation course'] !=  ]

# %%
# math score
df['math score'] = pd.to_numeric(df['math score'], errors= 'coerce')

# %%
# reading score
df['reading score'] = pd.to_numeric(df['reading score'], errors= 'coerce')

# %%
# Date_of _Evalution
df = df[df['Date_of _Evalution'] != '-']

# %%
# check unique values of all columns after removing noise
for i in df.columns:
    print(df[i].unique())
# Out:
# ['Alphabeta12' 'Alphabeta13' 'Alphabeta14' 'Alphabeta15' 'Alphabeta16'
#  'Alphabeta17' 'Alphabeta18' 'Alphabeta19' 'Alphabeta20' 'Alphabeta21'
#  'Alphabeta22' 'Alphabeta23' 'Alphabeta24' 'Alphabeta25' 'Alphabeta26'
#  'Alphabeta27' 'Alphabeta28' 'Alphabeta29' 'Alphabeta30' 'Alphabeta31'
#  'Alphabeta32' 'Alphabeta33' 'Alphabeta34' 'Alphabeta35' 'Alphabeta36'
#  'Alphabeta37' 'Alphabeta38' 'Alphabeta39' 'Alphabeta40' 'Alphabeta41'
#  'Alphabeta42' 'Alphabeta43' 'Alphabeta44' 'Alphabeta45' 'Alphabeta46'
#  'Alphabeta47' 'Alphabeta48' 'Alphabeta49' 'Alphabeta50' 'Alphabeta51'
#  'Alphabeta52' 'Alphabeta53' 'Alphabeta54' 'Alphabeta55' 'Alphabeta56'
#  'Alphabeta57' 'Alphabeta58' 'Alphabeta59' 'Alphabeta60' 'Alphabeta61'
#  'Alphabeta62' 'Alphabeta63' 'Alphabeta64' 'Alphabeta65' 'Alphabeta66'
#  'Alphabeta67' 'Alphabeta68' 'Alphabeta69' 'Alphabeta70' 'Alphabeta71'
#  'Alphabeta72' 'Alphabeta73' 'Alphabeta74' 'Alphabeta75' 'Alphabeta76'
# ...

# %%
# check null values
df.isnull().sum()/len(df)*100
# Out:
# StudentId                      0.000000
# gender                         0.000000
# group                          0.000000
# parental level of education    0.100806
# lunch                          0.100806
# test preparation course        0.000000
# math score                     0.201613
# reading score                  0.201613
# writing score                  0.100806
# Date_of _Evalution             0.100806
# dtype: float64

# %%
df.dtypes
# Out:
# StudentId                       object
# gender                          object
# group                           object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# Date_of _Evalution              object
# dtype: object

# %%
# handle null
df.dropna(inplace=True)

# %%
for i in df._get_numeric_data().columns:
    df[i] = df[i].astype('int32')

# %%
df.shape
# Out:
# (984, 10)

# %%
# check statistical information

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  984.000000     984.000000     984.000000
# mean    66.446138      69.038618      67.790650
# std     15.379735      14.700417      15.579314
# min     13.000000      28.000000      23.000000
# 25%     56.000000      60.000000      58.000000
# 50%     67.000000      70.000000      68.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
# What is the maximum, minimum, and average Math score?
df['math score'].agg(['max', 'min' ,'mean'])
# Out:
# max     100.000000
# min      13.000000
# mean     66.446138
# Name: math score, dtype: float64

# %%
# What is the maximum, minimum, and average Reading score of male?
df[df['gender']=='male']['reading score'].agg(['max', 'min' ,'mean'])
# Out:
# max     100.000000
# min      28.000000
# mean     66.387033
# Name: reading score, dtype: float64

# %%
df

# %%
# Calculate each student's average score.
df['avg_score'] = ((df['math score']+df['reading score']+df['writing score'])//3)
df[['StudentId', 'avg_score']]
# Out:
#          StudentId  avg_score
# 0      Alphabeta12         65
# 2      Alphabeta14         56
# 3      Alphabeta15         74
# 4      Alphabeta16         73
# 5      Alphabeta17         72
# 6      Alphabeta18         61
# 7      Alphabeta19         88
# 8      Alphabeta20         61
# 9      Alphabeta21         44
# 10     Alphabeta22         89
# 11     Alphabeta23         85
# 12     Alphabeta24         83
# 14     Alphabeta26         84
# 15     Alphabeta27         62
# 16     Alphabeta28         49
# 17     Alphabeta29         60
# 18     Alphabeta30         37
# 19     Alphabeta31         34
# 20     Alphabeta32         82
# 21     Alphabeta33         55
# 22     Alphabeta34         71
# 23     Alphabeta35         51
# 24     Alphabeta36         38
# 25     Alphabeta37         46
# 26     Alphabeta38         56
# 27     Alphabeta39         66
# 28     Alphabeta40         84
# 29     Alphabeta41         46
# 30     Alphabeta42         81
# 31     Alphabeta43         75
# ...

# %%
# Count of unique values present in group, gender, parental level of education and lunch columns.

# %%
df[['gender', 'group', 'parental level of education', 'lunch']].nunique()
# Out:
# gender                         2
# group                          5
# parental level of education    6
# lunch                          2
# dtype: int64

# %%
# Determine in Which year student's average score is maximum?
# (Average score - Average of maths, reading and writing scores)

# %%
df['Date_of _Evalution'] = pd.to_datetime(df['Date_of _Evalution'])
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17136\3116942652.py:1: UserWarning: Parsing '17/07/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date_of _Evalution'] = pd.to_datetime(df['Date_of _Evalution'])
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17136\3116942652.py:1: UserWarning: Parsing '19/09/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date_of _Evalution'] = pd.to_datetime(df['Date_of _Evalution'])
# C:\Users\abhis\AppData\Local\Temp\ipykernel_17136\3116942652.py:1: UserWarning: Parsing '31/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date_of _Evalution'] = pd.to_datetime(df['Date_of _Evalution'])
# ...

# %%
df[df['avg_score']==df['avg_score'].max()]['Date_of _Evalution'].dt.year
# Out:
# 148    2011
# 281    2014
# 550    2015
# 634    2011
# 825    2014
# Name: Date_of _Evalution, dtype: int64

# %%
#  What were the first date and last date of evaluation?
df['Date_of _Evalution'].agg(['max', 'min'])
# Out:
# max   2018-12-29
# min   2008-04-12
# Name: Date_of _Evalution, dtype: datetime64[ns]

# %%
# What is the most frequent weekday of evaluation?
df['Date_of _Evalution'].dt.weekday.mode()
# Out:
# 0    5
# Name: Date_of _Evalution, dtype: int64

# %%
x = df['Date_of _Evalution'].dt.weekday.value_counts()
x.sort_values(ascending=False).head(1)
# Out:
# 5    165
# Name: Date_of _Evalution, dtype: int64

# %%
# Print the monthly total number of evaluations in the year between 2012 to 2019.

# %%
df['Year'] = df['Date_of _Evalution'].dt.year

# %%
df['Month'] = df['Date_of _Evalution'].dt.month

# %%
y = df[(df['Year'] >= 2012) & (df['Year'] <= 2019)]
y.groupby(['Year', 'Month'])['Date_of _Evalution'].count()              ####################################################
# Out:
# Year  Month
# 2012  1         3
#       2         7
#       3        10
#       4         7
#       5         6
#       6         5
#       7        11
#       8         6
#       9        11
#       10        8
#       11        7
#       12       12
# 2013  1        10
#       2         8
#       3         7
#       4         9
#       5         3
#       6         6
#       7         8
#       8         7
#       9         5
#       10        7
#       11       11
#       12        9
# 2014  1         7
#       2        14
#       3         6
#       4        11
#       5         8
#       6         8
#       7        11
#       8         5
#       9         8
#       10        8
#       11        4
#       12       10
# 2015  1         9
#       2         3
#       3         9
#       4         7
#       5         7
#       6         6
#       7         7
#       8         6
#       9        11
#       10        8
#       11        7
#       12        6
# 2016  1        14
# ...

# %%
df['Year'].dtype
# Out:
# dtype('int64')

# %%
# Create a dataframe where the index will be group type and columns will be minimum, maximum, and average Maths score.

# %%
x = df.groupby('group')['math score'].agg(['min', 'max', 'mean'])
x
# Out:
#          min  max       mean
# group
# group A   33   94  65.215190
# group B   25   99  63.280788
# group C   13  100  63.174051
# group D   13  100  69.271318
# group E   33  100  74.609375

# %%
# Print each test preparation course first and last date of evaluation.

# %%
df.groupby('test preparation course')['Date_of _Evalution'].agg(['max', 'min'])
# Out:
#                                max        min
# test preparation course
# completed               2018-12-29 2008-04-12
# none                    2018-12-28 2008-09-12

# %%
# A. Find the person whose reading score, writing score, and Math score is greater than
# 60 and their average of reading score, Math score, and writing score greater than 70.

# %%
z = df[(df['reading score'] > 60) & (df['writing score'] > 60) & (df['math score'] > 60) & (df['avg_score'] > 70)]

# %%
# B. Take the mean of each group for students qualifying the above condition       ####################################

# %%
df['Total_score'] = df['reading score'] + df['writing score'] + df['math score']
df
# Out:
#          StudentId  gender    group parental level of education         lunch  \
# 0      Alphabeta12    male  group A                 high school      standard
# 2      Alphabeta14    male  group E                some college  free/reduced
# 3      Alphabeta15    male  group B                 high school      standard
# 4      Alphabeta16    male  group E          associate's degree      standard
# 5      Alphabeta17  female  group D                 high school      standard
# 6      Alphabeta18  female  group A           bachelor's degree      standard
# 7      Alphabeta19    male  group E                some college      standard
# 8      Alphabeta20    male  group D                 high school      standard
# 9      Alphabeta21    male  group C                some college  free/reduced
# 10     Alphabeta22    male  group E                some college      standard
# 11     Alphabeta23  female  group D                 high school      standard
# ...

# %%
df.groupby('group')['Total_score'].mean()
# Out:
# group
# group A    200.746835
# group B    196.172414
# group C    194.424051
# group D    213.531008
# group E    217.281250
# Name: Total_score, dtype: float64

# %%
df.columns
# Out:
# Index(['StudentId', 'gender', 'group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Date_of _Evalution', 'avg_score', 'Year', 'Month',
#        'Total_score'],
#       dtype='object')

# %%
# handle outlier

# %%
col_n = ['math score', 'reading score', 'writing score', 'avg_score']

# %%
for i in col_n:
  percentile25=df[i].quantile(0.25)
  percentile75=df[i].quantile(0.75)
  iqr=percentile75-percentile25
  upper_limit=percentile75+(1.5*iqr)
  lower_limit=percentile25-(1.5*iqr)
  df=df[df[i]<upper_limit]
  df=df[df[i]>lower_limit]
  plt.figure()
  sns.boxplot(y=i,data=df)

# %% [markdown]
# Make visuals with matplotlib & seaborn

# %%
# line plot

# %%
# Yearly monthwise analysis of avg marks

# %%
# matplotlib# # matplotlib
# plt.figure(figsize=(10,10))
df.groupby('Month').agg({'avg_score':"sum"}).plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
# Out:
# Index(['StudentId', 'gender', 'group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Date_of _Evalution', 'avg_score', 'Year', 'Month',
#        'Total_score'],
#       dtype='object')

# %%
# plt.figure(figsize=(10,10))
sns.lineplot(x=df['Month'], y=df['avg_score'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='avg_score'>

# %%
# Barplot

# %%
plt.figure(figsize=(3,5))
sns.barplot(x=df['test preparation course'], y=df['avg_score'], hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='avg_score'>

# %%
df.columns
# Out:
# Index(['StudentId', 'gender', 'group', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Date_of _Evalution', 'avg_score', 'Year', 'Month',
#        'Total_score'],
#       dtype='object')

# %%
# scatter plot
sns.scatterplot(x=df['writing score'], y=df['avg_score'], hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='avg_score'>

# %%
# correlation
x = df[['math score','reading score','writing score','avg_score']]
x.corr()
# Out:
#                math score  reading score  writing score  avg_score
# math score       1.000000       0.813800       0.800123   0.916781
# reading score    0.813800       1.000000       0.952052   0.969069
# writing score    0.800123       0.952052       1.000000   0.965264
# avg_score        0.916781       0.969069       0.965264   1.000000

# %%
# heatmap
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
# pairplot
sns.pairplot(x)

# %%
sns.violinplot(x=df['group'], y=df['avg_score'])
# Out:
# <AxesSubplot:xlabel='group', ylabel='avg_score'>
